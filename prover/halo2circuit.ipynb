# %% [markdown]
# ## THE CIRCUIT CONFIGURATION

# %%
# check if notebook is in colab
try:
    import google.colab
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "ezkl"])
    subprocess.check_call([sys.executable, "-m", "pip", "install", "onnx"])

# rely on local installation of ezkl if the notebook is not in colab
except:
    pass

import os
import json
import ezkl
import pandas as pd

import torch
from torchvision import transforms
from PIL import Image

import logging
import os
import sys
import sys
import time
from datetime import datetime

current_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.append(project_root)
from training.defineSNN import MODSiameseBambooNN


# uncomment for more descriptive logging
FORMAT = '%(levelname)s %(name)s %(asctime)-15s %(filename)s:%(lineno)d %(message)s'
logging.basicConfig(format=FORMAT)
logging.getLogger().setLevel(logging.INFO)


# Specify all the files we need
model_path = os.path.join('ezkl-outputs/snn.onnx')
compiled_model_path = os.path.join('ezkl-outputs/snn.ezkl')
pk_path = os.path.join('ezkl-outputs/pk.key')
vk_path = os.path.join('ezkl-outputs/vk.key')
settings_path = os.path.join('ezkl-outputs/settings.json')
srs_path = os.path.join('ezkl-outputs/kzg.srs')
data_path = os.path.join('ezkl-outputs/input.json')
cal_path = os.path.join('ezkl-outputs/cal_data.json')
##
sol_code_path = os.path.join('../contracts/Verifier.sol')
abi_path = os.path.join('ezkl-outputs/Verifier.abi')
proof_path = os.path.join('ezkl-outputs/proof.json')

# %%
### Assign benchmark test name each time a new test is executed to save its results into a file

timestamp = datetime.now().strftime("%m_%d_%H:%M")
test_name = f"test_2___{timestamp}"
test_time_and_size_path = os.path.join(f'../benchmark/{test_name}_time_and_size.txt')
#test_gas_path = os.path.join(f'../benchmark/{test_name}_gas.html')

print(test_name)
# Out:
# test_2___01_08_18:58

# %%
### Load the image pair as input ready for inference
class SiameseImageLoader:
    def __init__(self, transform=None):
        self.transform = transform

    def load_and_transform_pair(self, image1_path, image2_path):
        img1 = Image.open(image1_path).convert('L')
        img2 = Image.open(image2_path).convert('L')

        if self.transform:
            img1 = self.transform(img1)
            img2 = self.transform(img2)

        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        img1 = img1.to(device)
        img2 = img2.to(device)

        return img1, img2

transform = transforms.Compose([
    transforms.Resize((10, 10)),
    transforms.ToTensor(),
])

# Example inputs (TrueNegative, TruePositive, FalseNegative)
# (FalseNegative were produced with a growing rate of bamboo higher than what the model was trained on)
siamese_loader = SiameseImageLoader(transform)
image1_path = "TestValid_t1.jpeg"
image2_path = "TestValid_t0.jpeg"
img1, img2 = siamese_loader.load_and_transform_pair(image1_path, image2_path) # Separate tensors for each image
img1 = img1.unsqueeze(0)
img2 = img2.unsqueeze(0)

print(img1.size())
# Out:
# torch.Size([1, 1, 10, 10])

# %%
# Load the trained nn model and make inference on test inputs
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
loaded_model = MODSiameseBambooNN().to(device)
loaded_model.load_state_dict(torch.load('../training/trained_simplesnn_lr_0.01.pth', map_location=torch.device('cpu')))
loaded_model.eval()

with torch.no_grad():
    finalout = loaded_model(img1, img2)
    predicted_label = (torch.sigmoid(finalout) > 0.5).item()

print(f'Same class probability: {torch.sigmoid(finalout)}')
print(f'Predicted Label: {predicted_label}')

# Calculate the total number of parameters
total_params = sum(p.numel() for p in loaded_model.parameters())
print(f'Total Parameters: {total_params}')
# Out:
# Same class probability: tensor([[0.6949]])
# Predicted Label: True
# Total Parameters: 30849
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.

# %%
# Export the loaded Siamese Network model to ONNX
torch.onnx.export(loaded_model,                      # loaded Siamese Network model
                  (img1, img2),                      # model input (or a tuple for multiple inputs)
                  model_path,                        # where to save the ONNX model
                  export_params=True,                # store the trained parameter weights inside the model file
                  opset_version=14,                  # the ONNX version to export the model to
                  do_constant_folding=True,          # whether to execute constant folding for optimization
                  input_names = ['input'],   # the model's input names
                  output_names = ['output'], # the model's output names
                  dynamic_axes={'input' : {0 : 'batch_size'},    # variable length axes
                                'output' : {0 : 'batch_size'}})



# Move tensors from GPU to CPU
img1_cpu = img1.cpu()
img2_cpu = img2.cpu()
print(img1_cpu.size())

# Serialize data into a JSON file
input_data = [
    img1_cpu.detach().numpy().reshape([-1]).tolist(),
    img2_cpu.detach().numpy().reshape([-1]).tolist(),
]

data = dict(input_data=input_data)
json.dump(data, open(data_path, 'w'))
# Out:
# torch.Size([1, 1, 10, 10])

# %%
# *** Providing the calibrate settings function with a larger and broader range of sample inputs.


csv_path = '../training/dataset/forest_dataset.csv'
df = pd.read_csv(csv_path)

# Construct the full paths to the images
img1_files = [os.path.join('..', 'training', path) for path in df['imageT0'].iloc[:20]]
img2_files = [os.path.join('..', 'training', path) for path in df['imageT1'].iloc[:20]]

img1_list = []
img2_list = []
for img1_path, img2_path in zip(img1_files, img2_files):
    img1, img2 = siamese_loader.load_and_transform_pair(img1_path, img2_path)
    img1 = img1.unsqueeze(0).cpu().detach().numpy().reshape([-1]).tolist()
    img2 = img2.unsqueeze(0).cpu().detach().numpy().reshape([-1]).tolist()
    img1_list.extend(img1) # don't use .append bc it should look like [[xxx...],[yyy...]]
    img2_list.extend(img2)

data = dict(input_data = [img1_list, img2_list])
# Serialize data into file:
json.dump( data, open(cal_path, 'w' ))

# %%
#For ezkl to compute a snark, it needs some settings to determine how to create the circuit.
#This cell instantiates some parameters that determine the circuit shape, size etc
py_run_args = ezkl.PyRunArgs()
py_run_args.input_visibility = "private"
py_run_args.output_visibility = "public"
py_run_args.param_visibility = "fixed" # "fixed" for params means that the committed to params are used for all proofs
py_run_args.variables = [("batch_size", 1)]

# !RUST_LOG=trace
# TODO: Dictionary outputs
res = ezkl.gen_settings(model_path, settings_path, py_run_args=py_run_args)
assert res == True
print("gen_settings OK")

# *** SCALES is one of main knobs you can turn to trade off accuracy for proving efficiency
# Under the hood calibration iterates over the scales array to see how precise you can go before failure. 
# For example if 7 fails it falls back to 1.
# (Right now the default scales values for the resources target is 8-10 and 10-13  for accuracy)
#res = ezkl.calibrate_settings(cal_path, model_path, settings_path, "resources", scales = [1, 7])
res = ezkl.calibrate_settings(cal_path, model_path, settings_path, "accuracy")
assert res == True
# Out:
# INFO ezkl.graph.model 2024-01-08 18:58:40,694 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 18
model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:00:50,171 model.rs:1473 model uses 57780 rows (coord=115561, constants=98889)
# INFO ezkl.graph 2024-01-08 19:00:50,173 mod.rs:748 input scales: [10, 10]
# INFO ezkl.graph.model 2024-01-08 19:00:50,877 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:00:50,889 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:00:51,567 model.rs:1473 model uses 57780 rows (coord=115561, constants=98889)
# INFO ezkl.graph 2024-01-08 19:00:51,574 mod.rs:1025 setting lookup_range to: (-22266036, 23906110), setting logrows to: 26
# INFO ezkl.graph.model 2024-01-08 19:00:51,584 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:00:51,803 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:00:51,814 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:00:52,412 model.rs:1473 model uses 57780 rows (coord=115561, constants=98889)
# INFO ezkl.graph 2024-01-08 19:00:52,414 mod.rs:748 input scales: [10, 10]
# INFO ezkl.graph.model 2024-01-08 19:00:53,107 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:00:53,108 model.rs:1398 calculating num of constraints using dummy model layout...
# ...
# INFO ezkl.graph 2024-01-08 19:07:51,293 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:07:51,631 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:07:51,699 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:07:51,701 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:07:51,972 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:07:51,977 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:07:52,292 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:07:52,371 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:07:52,372 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:07:52,626 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:07:52,629 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:07:52,898 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:07:52,958 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:07:52,959 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:07:53,193 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:07:53,195 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:07:53,483 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:07:53,555 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:07:53,556 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:07:54,241 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:07:54,243 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:07:54,559 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:07:54,637 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:07:54,639 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:07:54,871 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:07:54,874 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:07:55,135 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:07:55,202 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:07:55,203 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:07:55,417 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:07:55,419 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:07:55,745 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:07:55,820 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:07:55,822 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:07:56,040 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:07:56,042 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:07:56,363 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:07:56,455 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:07:56,457 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:07:56,756 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:07:56,759 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:07:57,036 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:07:57,379 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:07:57,382 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:07:57,713 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:07:57,716 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:07:58,020 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:07:58,106 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:07:58,109 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:07:58,370 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:07:58,372 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:07:58,687 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:07:58,755 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:07:58,756 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:07:58,977 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:07:58,986 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:07:59,593 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:07:59,643 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:07:59,646 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:07:59,914 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:07:59,917 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:00,202 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:00,289 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:00,290 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:00,495 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:00,497 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:00,801 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:00,865 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:00,867 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:01,142 model.rs:1473 model uses 56785 rows (coord=113571, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:01,146 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:01,458 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:01,533 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:01,542 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:01,791 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:01,793 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:02,017 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:02,095 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:02,097 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:02,288 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:02,290 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:02,617 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:02,688 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:02,689 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:02,949 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:02,951 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:03,637 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:03,703 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:03,705 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:03,983 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:03,985 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:04,318 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:04,427 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:04,428 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:04,675 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:04,685 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:05,202 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:05,274 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:05,275 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:05,523 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:05,530 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:05,885 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:05,949 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:05,950 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:06,155 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:06,157 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:06,430 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:06,511 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:06,512 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:06,751 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:06,754 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:07,028 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:07,094 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:07,104 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:07,342 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:07,344 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:07,659 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:07,728 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:07,729 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:08,249 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:08,251 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:08,548 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:08,611 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:08,621 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:08,862 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:08,865 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:09,152 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:09,230 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:09,231 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:09,479 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:09,482 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:09,809 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:09,890 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:09,893 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:10,152 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:10,155 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:10,655 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:10,735 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:10,736 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:11,037 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:11,041 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:11,755 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:11,849 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:11,850 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:12,157 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:12,160 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:12,469 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:12,552 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:12,558 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:12,827 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:12,836 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:13,163 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:13,250 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:13,257 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:13,535 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:13,543 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:13,828 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:13,894 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:13,900 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:14,162 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:14,164 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:14,497 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:14,585 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:14,586 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:14,851 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:14,861 mod.rs:748 input scales: [13, 13]
# INFO ezkl.graph.model 2024-01-08 19:08:15,184 model.rs:775 set batch_size to 1
# INFO ezkl.graph.model 2024-01-08 19:08:15,244 model.rs:477 model has 1 instances
# INFO ezkl.graph.model 2024-01-08 19:08:15,246 model.rs:1398 calculating num of constraints using dummy model layout...
# INFO ezkl.graph.model 2024-01-08 19:08:15,828 model.rs:1473 model uses 56489 rows (coord=112978, constants=98895)
# INFO ezkl.graph 2024-01-08 19:08:15,832 mod.rs:748 input scales: [13, 13]

# %%
# Now compile the model into a circuit
res = ezkl.compile_circuit(model_path, compiled_model_path, settings_path)
assert res == True
# Out:
# INFO ezkl.graph.model 2024-01-08 19:08:16,367 model.rs:775 set batch_size to 1

# %%
# get public srs from kzg ceremony, saved to srs path.
res = ezkl.get_srs(settings_path)
assert res == True
# Out:
# INFO ezkl.execute 2024-01-08 19:08:16,799 execute.rs:469 SRS already exists at that path

# %%
# Setup the circuit and make sure the keys are generated afterwards.
start_time = time.time()

res = ezkl.setup(
        compiled_model_path,
        vk_path,
        pk_path,
    )

end_time = time.time()

execution_time = end_time - start_time

vk_size = os.path.getsize(vk_path)
pk_size = os.path.getsize(pk_path)

with open(test_time_and_size_path, 'a') as f:
   f.write(f"Verification key size: {vk_size} bytes\n")
   f.write(f"Proving key size: {pk_size} bytes\n")
   f.write(f"Setup time: {execution_time}\n")

assert res == True
assert os.path.isfile(vk_path)
assert os.path.isfile(pk_path)
# Out:
# INFO ezkl.pfsys.srs 2024-01-08 19:08:16,908 srs.rs:23 loading srs from "/home/manu/.ezkl/srs/kzg24.srs"
# INFO ezkl.execute 2024-01-08 19:08:36,907 execute.rs:1782 downsizing params to 24 logrows
# INFO ezkl.graph.vars 2024-01-08 19:08:36,909 vars.rs:422 number of blinding factors: 5
# INFO ezkl.graph.model 2024-01-08 19:08:36,912 model.rs:1076 configuring model
# WARNING ezkl.circuit.table 2024-01-08 19:08:36,913 table.rs:167 Using 15 columns for non-linearity table.
# WARNING ezkl.circuit.table 2024-01-08 19:08:36,918 table.rs:167 Using 15 columns for non-linearity table.
# WARNING ezkl.circuit.table 2024-01-08 19:08:36,951 table.rs:167 Using 15 columns for non-linearity table.
# INFO ezkl.graph 2024-01-08 19:08:36,957 mod.rs:1361 circuit size:
#  {
#   "num_advice_columns": 6,
#   "num_challenges": 0,
#   "num_fixed": 61,
#   "num_instances": 1,
#   "num_selectors": 26
# }
# thread '<unnamed>' panicked at /root/.cargo/git/checkouts/halo2-049b997cf7195aea/57b9123/halo2_proofs/src/poly/domain.rs:55:9:
# assertion failed: extended_k <= F::S
# note: run with `RUST_BACKTRACE=1` environment variable to display a backtrace
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# Cell In[10], line 4
#       1 # Setup the circuit and make sure the keys are generated afterwards.
#       2 start_time = time.time()
# ----> 4 res = ezkl.setup(
#       5         compiled_model_path,
#       6         vk_path,
#       7         pk_path,
#       8     )
#      10 end_time = time.time()
#      12 execution_time = end_time - start_time
#
# PanicException: assertion failed: extended_k <= F::S

# %%
# GENERATE the verifier associated with the circuit
try:
    import google.colab
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "solc-select"])
    # !solc-select install 0.8.20
    # !solc-select use 0.8.20
    # !solc --version
# rely on local installation if the notebook is not in colab
except:
    pass

# %%
res = ezkl.create_evm_verifier(
        vk_path,
        settings_path,
        sol_code_path,
        abi_path
    )
assert res == True
assert os.path.isfile(sol_code_path)

# %% [markdown]
# ## PROVE and VERIFY
# ### here we will generate and verify a proof locally. Then we will format the inputs and the proof in a way compatible for the evm verifier

# %%
witness_path = os.path.join('ezkl-outputs/witness.json')
# generate the witness file
res = ezkl.gen_witness(data_path, compiled_model_path, witness_path)
assert os.path.isfile(witness_path)

# %%
# !!!Generate the proof!!!
start_time = time.time()

proof = ezkl.prove(
        witness_path,
        compiled_model_path,
        pk_path,
        proof_path,
        "single",
    )

end_time = time.time()

execution_time = end_time - start_time
with open(test_time_and_size_path, 'a') as f:
   f.write(f"Proving time: {execution_time}\n")

print(proof)
assert os.path.isfile(proof_path)

# %%
# Sanity check off-chain verification
start_time = time.time()

res = ezkl.verify(
        proof_path,
        settings_path,
        vk_path,
    )

end_time = time.time()

execution_time = end_time - start_time
with open(test_time_and_size_path, 'a') as f:
   f.write(f"Verification (locally) time: {execution_time}\n")

assert res == True
print("verified locally")

# %%
# Get input data for the verifier contract (evmInputs.json)
onchain_input_array = []
# avoiding printing last comma
formatted_output = "["
for i, value in enumerate(proof["instances"]):
    for j, field_element in enumerate(value):
        onchain_input_array.append(ezkl.vecu64_to_felt(field_element))
        formatted_output += str(onchain_input_array[-1])
        if j != len(value) - 1:
            formatted_output += ", "
    formatted_output += "]"
print("form output",formatted_output )
    
input_list = [int(entry, 0) for entry in formatted_output.strip('[]').split(', ')]
quoted_list = [format(entry, "#066x") for entry in input_list]
json_data = {
    "instances": quoted_list,
    "proof": "0x" + proof["proof"]
}
with open('evmInputs.json', 'w') as json_file:
    json.dump(json_data, json_file, indent=2)
print("Saved evmInputs.json: ", json_data)
